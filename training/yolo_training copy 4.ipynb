# %% [markdown]
# # Установка зависимостей

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126

# %%
# !pip install -U ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.38-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached numpy-2.4.4-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pillow-12.2.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.11.0-cp311-cp311-win_amd64.whl.metadata (29 kB)
# ...
#   Using cached torchvision-0.26.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached polars-1.39.3-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# ...

# %% [markdown]
# # Импорт библиотек

# %%
from ultralytics import YOLO
import os
from pathlib import Path

# %%
#model = YOLO('runs\\detect\\runs\\detect\\yolo_train\\weights\\best.pt')
model = YOLO('yolo26x.pt')

results = model.train(
    data='ABOships-PLUS\dataset.yaml',
    epochs=80,
    imgsz=640,
    batch=8,
    # оптимальный подбор батча 16
    device='cuda',
    workers=8,
    project='runs/detect',
    save = True,
    save_period = 5,
    name='yolo_train_v26x',
    exist_ok=False,
    pretrained=True,
    optimizer = 'AdamW',
    freeze = 10,
    # заморожен только backbone
    #patience = 25,
    seed = 39,
    #resume = True,  
    lr0=0.0001,
    lrf=0.48,
    #momentum=0.9,
    #weight_decay=0.0001,
    warmup_epochs=3.0,
    warmup_bias_lr=0.1,
    close_mosaic = 10,
    # box=7.5,
    # cls=0.5,
    # dfl=1.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    amp=True,
    deterministic=True
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.39 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.38  Python-3.11.9 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2060, 12288MiB)
# ...

# %% [markdown]
# # Экспорт модели в другие форматы

# %%
best_model.export(
    format='onnx',
    imgsz=640,
    keras=False,
    optimize=False,
    half=False,
    int8=False,
    dynamic=False,
    simplify=False
)
print("Модель экспортирована")
